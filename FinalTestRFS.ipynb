# %%
# load model from pickle file
import pandas as pd
import numpy as np
import joblib

# %%
testdata=pd.read_excel('t1.xlsx')

# %%
selected_features = ['ER', 'PgR', 'HER2', 'TrippleNegative', 'ChemoGrade', 'LNStatus','original_shape_Flatness', 'original_firstorder_90Percentile','original_firstorder_InterquartileRange', 'original_firstorder_Minimum','original_glszm_GrayLevelNonUniformity','original_glszm_SmallAreaEmphasis']
X_new=testdata[selected_features]
X_new
# Out:
#    ER  PgR  HER2  TrippleNegative  ChemoGrade  LNStatus  \
# 0   0    0     0                1           3         1
# 1   1    1     0                0           3         1
# 2   0    0     0                1           2         0
# 3   0    0     0                1           2         1
# 4   0    0     1                0           2         1
# 5   1    1     0                0           2         1
# 6   1    1     1                0           3         1
# 7   0    0     0                1           3         0
#
#    original_shape_Flatness  original_firstorder_90Percentile  \
# 0                 0.724080                          0.708860
# 1                 0.476173                          2.322627
# 2                 0.594470                          1.961740
# 3                 0.644471                          1.894963
# 4                 0.371714                          2.556516
# 5                 0.486030                          2.494679
# 6                 0.538655                          2.342025
# 7                 0.737872                          2.215187
#
#    original_firstorder_InterquartileRange  original_firstorder_Minimum  \
# 0                                0.406537                    -1.251833
# 1                                0.730463                    -1.106491
# 2                                0.509910                    -1.025610
# 3                                0.679615                    -2.145561
# 4                                0.901805                    -1.293126
# 5                                1.163922                    -1.159331
# 6                                1.194788                    -1.356408
# 7                                1.102683                    -1.065968
#
#    original_glszm_GrayLevelNonUniformity  original_glszm_SmallAreaEmphasis
# 0                              27.545455                          0.403535
# 1                              78.025000                          0.444391
# 2                              72.027027                          0.534549
# 3                              40.047619                          0.534279
# 4                              61.123077                          0.517795
# 5                              81.024096                          0.401346
# 6                              16.111111                          0.022413
# 7                             120.016393                          0.429904

# %%
#Data cleaning
X_new.replace(999, np.nan, inplace=True)
X_new.fillna(X_new.median(), inplace=True)
# Out:
# C:\Users\prave\AppData\Local\Temp\ipykernel_23592\1139305188.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_new.replace(999, np.nan, inplace=True)
# C:\Users\prave\AppData\Local\Temp\ipykernel_23592\1139305188.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_new.fillna(X_new.median(), inplace=True)

# %%
loaded_model = joblib.load('rf_regressor.joblib')

# Assuming X_new is your new data
predictions = loaded_model.predict(X_new)

# Display or use the predictions as needed
print(predictions)
# Out:
# [ 70.15021552  54.75136155 109.9732418   81.02177088  55.90234021
#   95.73522194  81.78678036  78.93430501]
